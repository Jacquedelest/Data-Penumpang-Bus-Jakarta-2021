# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacquedelest/Data-Penumpang-Bus-Jakarta-2021/blob/main/NewYork_Electric_Supply_Rates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **New York Power Authority (NYPA) Electric Supply Rates - Business Customers: Beginning 2012**
#
# `Metadata Updated: November 12, 2020`
#
# The New York Power Authority provides low-cost power to help support jobs statewide while reducing public-sector costs. The Authority’s customer base includes large and small businesses, not-for-profit organizations, community-owned electric systems and rural electric cooperatives and government entities. This data includes the electric supply rates that the Authority offers to its Business Customers under different power programs.
#
# Dataset can be download here: *https://catalog.data.gov/dataset/new-york-power-authority-nypa-electric-supply-rates-business-customers-beginning-2012*

# %% [markdown]
# Import needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading dataset is important before we clean and analyze data

# %%
ny_electricsupply = pd.read_csv("New_York_Power_Authority__NYPA__Electric_Supply_Rates_-_Business_Customers__Beginning_2012.csv")
ny_electricsupply.head()
# Out:
#                                        Customer Type  ...  Data as of
# 0                       Direct Sale Western New York  ...  04/30/2016
# 1  Utilities, Municipal and Cooperative Systems a...  ...  12/31/2012
# 2                                  Replacement Power  ...  12/31/2012
# 3                                    Expansion Power  ...  12/31/2012
# 4                        Aluminum Company of America  ...  12/31/2012
#
# [5 rows x 7 columns]

# %%
ny_electricsupply.tail()
# Out:
#                                      Customer Type  ... Data as of
# 574  Direct Sale ReCharge New York - Blended Power  ...        NaN
# 575  Direct Sale ReCharge New York - Blended Power  ...        NaN
# 576      Wholesale ReCharge New York - Hydro Power  ...        NaN
# 577                   Direct Sale Western New York  ...        NaN
# 578               Direct Sale Western New York - 2  ...        NaN
#
# [5 rows x 7 columns]

# %% [markdown]
# New York Independent System Operator Zone (Column NYISO Zone) is New York Control Area Load Zone![NY Control Aread Load Zones 1.png](data:image/png;base64,...)![NY Control Area Load Zones 2.png](data:image/png;base64,...)

# %% [markdown]
# Check information about dataset

# %%
ny_electricsupply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer Type                   579 non-null    object
#  1   NYISO Zone                      362 non-null    object
#  2   Demand Rate ($/kW)              525 non-null    float64
#  3   Energy Rate (mills/kWh)         548 non-null    float64
#  4   Composite Rate Load Factor (%)  494 non-null    float64
#  5   Composite Rate (mills/kWh)      494 non-null    float64
#  6   Data as of                      562 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 31.8+ KB

# %% [markdown]
# Checking for missing values

# %%
ny_electricsupply.isnull().sum()
# Out:
# Customer Type                       0
# NYISO Zone                        217
# Demand Rate ($/kW)                 54
# Energy Rate (mills/kWh)            31
# Composite Rate Load Factor (%)     85
# Composite Rate (mills/kWh)         85
# Data as of                         17
# dtype: int64

# %% [markdown]
# Change datatype of column **Data as of** to datetime

# %%
ny_electricsupply['Data as of'] = pd.to_datetime(ny_electricsupply['Data as of'])

# %% [markdown]
# Checking a summary of statistics

# %%
ny_electricsupply.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                       Customer Type  ...           Data as of
# count                                           579  ...                  562
# unique                                           13  ...                   32
# top     Direct Sale ReCharge New York - Hydro Power  ...  2019-10-31 00:00:00
# freq                                            164  ...                   36
# first                                           NaN  ...  2012-12-31 00:00:00
# last                                            NaN  ...  2021-01-31 00:00:00
# ...

# %%
ny_electricsupply['Demand Rate ($/kW)'].iplot(kind='hist', bins=100, xTitle='price', linecolor='black', yTitle='count', title='Demand Rate ($/kW)')
# Out:
# <div>
#
#
#             <div id="15adeb29-f8bf-48b5-8acb-05da0904709f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("15adeb29-f8bf-48b5-8acb-05da0904709f")) {
#                     Plotly.newPlot(
#                         '15adeb29-f8bf-48b5-8acb-05da0904709f',
# ...
